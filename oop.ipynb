# %%
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pygraphviz-1.11.zip (120 kB)
# ...
#      |████████████████████████████████| 294 kB 10.7 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
def hello_world():
    print("Hello World!")
    
hello_world()
# Out:
# Hello World!

# %%
def hello(name):
    print("Hello " + name + "!")
hello("Alex")
# Out:
# Hello Alex!

# %%
def hello(name, age):
    print("Hello " + name + "! You are " + str(age) + " years old.")
hello("Alex", 25)
# Out:
# Hello Alex! You are 25 years old.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def hello(self):
        print("Hello " + self.name + "! You are " + str(self.age) + " years old.")
        
        
alex = Person("Alex", 25)
andrew = Person("Andrew", 24)

alex.hello()
andrew.hello()
# Out:
# Hello Alex! You are 25 years old.
# Hello Andrew! You are 24 years old.

# %%
class Person:
    def __init__(self, name: str, age: int):
        self.name = name
        self.age = age
    def hello(self) -> None:
        print("Hello " + self.name + "! You are " + str(self.age) + " years old.")
    def goodbye(self) -> None:
        print("Goodbye " + self.name + "! You are " + str(self.age) + " years old.")
    
    
alex = Person("Alex", 25)
andrew = Person("Andrew", 24)

alex.hello()
andrew.hello()
alex.goodbye()
andrew.goodbye()
# Out:
# Hello Alex! You are 25 years old.
# Hello Andrew! You are 24 years old.
# Goodbye Alex! You are 25 years old.
# Goodbye Andrew! You are 24 years old.

# %%
print(f"Person andrew: {andrew}")
print(f"Person alex: {alex}")



print(f"Before Reassignment: {andrew.name}")
andrew.name = "Andrew Brill"
print(f"After Reassignment: {andrew.name}")

print(f"Before Reassignment: {alex.name}")
alex.name = "Alex Wenner"
print(f"After Reassignment: {alex.name}")
# Out:
# Person andrew: <__main__.Person object at 0x103e4fc70>
# Person alex: <__main__.Person object at 0x103e4fcd0>
# Before Reassignment: Andrew
# After Reassignment: Andrew Brill
# Before Reassignment: Alex
# After Reassignment: Alex Wenner
